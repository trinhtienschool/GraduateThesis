# %% [markdown]
# Import một số thư viện

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
import os

# %% [markdown]
# Kết nối xuống driver

# %%
#Connect to gg drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Tải trained glove và dataset

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks/Source_code/LSTM_data/LSTM_dataset")

# %%
raw_data = pd.read_csv('preprocessed_LSTM_dataset.csv')
raw_data.clean_text = raw_data.clean_text.astype(str)

# %%
raw_data
# Out:
#                                                     text sentiment  rate  \
# 0                             The camera is very slow :(   neutral   3.0
# 1      I was happy I got a case and a charger that wa...  negative   1.0
# 2      I bought this phone for my wife and I wanted t...  positive   5.0
# 3      HTC One in White is good; in black it is bette...  positive   5.0
# 4      This phone is definitely one of the fastest on...  positive   5.0
# ...                                                  ...       ...   ...
# 89995  Fast but hot. Which makes it run slower in hig...   neutral   3.0
# 89996                                     no devise help   neutral   3.0
# 89997  I love the watch/phone and everything it offer...   neutral   3.0
# 89998                                        Replacement   neutral   3.0
# 89999                                               GOOD   neutral   3.0
#
#                                                   tokens  \
# 0                                     ['camera', 'slow']
# 1      ['happy', 'got', 'case', 'charger', 'descripti...
# 2      ['bought', 'phone', 'wife', 'wanted', 'wait', ...
# 3      ['tc', 'one', 'white', 'good', 'black', 'bette...
# 4      ['phone', 'definitely', 'one', 'fastest', 'mar...
# ...                                                  ...
# 89995  ['fast', 'hot', 'makes', 'run', 'slower', 'hig...
# 89996                           ['no', 'devise', 'help']
# 89997  ['love', 'watch', 'phone', 'everything', 'offe...
# 89998                                    ['replacement']
# 89999                                           ['good']
#
#                                               clean_text
# 0                                            camera slow
# 1      happy got case charger description told phone ...
# 2      bought phone wife wanted wait month half leave...
# 3      tc one white good black better love new phone ...
# 4      phone definitely one fastest market moment dro...
# ...                                                  ...
# 89995  fast hot makes run slower high temperature sit...
# 89996                                     no devise help
# 89997  love watch phone everything offered keep freez...
# 89998                                        replacement
# 89999                                               good
#
# [90000 rows x 5 columns]

# %%
data = raw_data

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks/Source_code/LSTM_data/LSTM_pretrained_Standford_Glove/pretrained_100")

# %%
emmbed_dict = {}
with open('glove.6B.100d.txt','r') as f:
  for line in f:
    values = line.split()
    word = values[0]
    vector = np.asarray(values[1:],'float32')
    emmbed_dict[word]=vector

# %%
emmbed_dict['the'].shape[0]
# Out:
# 100

# %% [markdown]
# Thực hiện Tokenize đoạn văn bản

# %%
vocab_size = 15000

tokenizer = Tokenizer(split=' ', num_words = vocab_size)
tokenizer.fit_on_texts(data['clean_text'].values)
print()
X = tokenizer.texts_to_sequences(data['clean_text'].values) #convert data to number
X = pad_sequences(X) # padding
print(X.shape[1]) #check size
MAX_LEN = X.shape[1]
words_to_index = tokenizer.word_index
# Out:
# 1607

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

top_n_words_index = dict(take(vocab_size, words_to_index.items()))
len(top_n_words_index)
# Out:
# 15000

# %% [markdown]
# Khởi tạo model LSTM

# %%
inp_dim = vocab_size+1
embed_dim = emmbed_dict['mobile'].shape[0]
hidden_nodes = 150 #dimension of LSTM output
output_dim = 3

print(vocab_size)
print(inp_dim)
# Out:
# 15000
# 15001

# %%
# Tạo matrix của trained glove 
emb_matrix = np.zeros((inp_dim, embed_dim))
for word, index in top_n_words_index.items():
  embedding_vector = emmbed_dict.get(word)
  if embedding_vector is not None:
    emb_matrix[index, :] = embedding_vector

# %%
model = Sequential()
#Embedding each row of X ("X.shape[1]" len) into dense vectors "embed_dim"
# model.add(Embedding(input_dim = vocab_size, output_dim = embed_dim, input_length = MAX_LEN)) 
model.add(Embedding(input_dim = inp_dim, output_dim = embed_dim, input_length = MAX_LEN, weights = [emb_matrix], trainable=False)) 
model.add(SpatialDropout1D(0.4))
model.add(LSTM(hidden_nodes, dropout=0.2, recurrent_dropout=0.2))  # add return_sequences=True if you want many-to-many LSTM model
model.add(Dense(output_dim,activation='softmax')) 
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1607, 100)         1500100
#
#  spatial_dropout1d (SpatialD  (None, 1607, 100)        0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 150)               150600
#
#  dense (Dense)               (None, 3)                 453
#
# =================================================================
# Total params: 1,651,153
# Trainable params: 151,053
# Non-trainable params: 1,500,100
# _________________________________________________________________
# None

# %% [markdown]
# Tạo tập train và test

# %%
Y = pd.get_dummies(data['sentiment']).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (72000, 1607) (72000, 3)
# (18000, 1607) (18000, 3)

# %%
Y_train
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1],
#        ...,
#        [0, 1, 0],
#        [1, 0, 0],
#        [0, 0, 1]], dtype=uint8)

# %% [markdown]
# Thực hiện train network

# %%
batch_size = 32
model.fit(X_train, Y_train, epochs = 4, batch_size=batch_size, verbose = 1)
# Out:
# Epoch 1/4
# 2250/2250 [==============================] - 5345s 2s/step - loss: 0.7654 - accuracy: 0.6489
# Epoch 2/4
#  719/2250 [========>.....................] - ETA: 1:01:29 - loss: 0.6885 - accuracy: 0.6921

# %% [markdown]
# Lưu model xuống drive

# %%
#Lưu model
model.save('LSTM_Model.h5')

# %%
#Lưu train và test
from numpy import savetxt
savetxt('X_train.csv', X_train, delimiter=',')
savetxt('Y_train.csv', Y_train, delimiter=',')
savetxt('X_test.csv', X_test, delimiter=',')
savetxt('Y_test.csv', Y_test, delimiter=',')

# %%
#Lưu tokenizer
import pickle

# saving
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('MAX_LEN.txt', 'w') as f:
  f.write('%d' % MAX_LEN)

# %% [markdown]
# Test sử dụng LSTM

# %%
twt = ["""product bad never buy"""]
#vectorizing the tweet by the pre-fitted tokenizer instance
twt = tokenizer.texts_to_sequences(twt)
#padding the tweet to have exactly the same shape as `embedding_2` input
twt = pad_sequences(twt, maxlen=MAX_LEN, dtype='int32', value=0)
print(twt)
sentiment = model.predict(twt,batch_size=1,verbose = 2)[0]
np.argmax(sentiment)
if(np.argmax(sentiment) == 0):
    print("negative")
elif (np.argmax(sentiment) == 1):
    print("neutral")
elif(np.argmax(sentiment) == 2):
  print("positive")

# %%
type(twt)

# %% [markdown]
# Validation và evaluation

# %%
validation_size = 1500

X_validate = X_test[-validation_size:]
Y_validate = Y_test[-validation_size:]
X_test = X_test[:-validation_size]
Y_test = Y_test[:-validation_size]
score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))

# %% [markdown]
# Dropout: 20% - https://towardsdatascience.com/choosing-the-right-hyperparameters-for-a-simple-lstm-using-keras-f8e9ed76f046

# %% [markdown]
# Tham khảo: https://colab.research.google.com/drive/1fAuZ7L8YQZrF-MyRXrdyR-Dh13AfA_X0
#
# https://towardsdatascience.com/sentiment-analysis-using-lstm-and-glove-embeddings-99223a87fe8e
